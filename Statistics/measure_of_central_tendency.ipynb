# %% [markdown]
# ### Measure Of Central Tendency

# %%
age = [12,21,23,45,65,43,56,45,32,67,54,34]

# %%
## Mean
import numpy as np
np.mean(age)
# Out:
# np.float64(41.416666666666664)

# %%
weights = [54,45,3454,34,67,54,56,75]

# %%
np.mean(weights)
# Out:
# np.float64(479.875)

# %%
import seaborn as sns
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
np.mean(df['total_bill'])
# Out:
# np.float64(19.78594262295082)

# %%
## Median
np.median(age)
# Out:
# np.float64(44.0)

# %%
## adding outlier to age
age = [12,21,23,45,65,43,56,45,32,67,54,34,200]

# %%
np.mean(age) # it is jumpong more
# Out:
# np.float64(53.61538461538461)

# %%
np.median(age) # it is not jumping more on adding outlier so it is used when there are outliers present.
# Out:
# np.float64(45.0)

# %%
pip install scipy
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.8 kB 640.0 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/60.8 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 463.5 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/44.5 MB 1.3 MB/s eta 0:00:34
#    ---------------------------------------- 0.1/44.5 MB 1.4 MB/s eta 0:00:31
#    ---------------------------------------- 0.2/44.5 MB 1.5 MB/s eta 0:00:29
#    ---------------------------------------- 0.3/44.5 MB 1.5 MB/s eta 0:00:29
#    ---------------------------------------- 0.3/44.5 MB 1.4 MB/s eta 0:00:32
#    ---------------------------------------- 0.4/44.5 MB 1.4 MB/s eta 0:00:31
# ...

# %%
## Mode
from scipy import stats
stats.mode(age)
# Out:
# ModeResult(mode=np.int64(45), count=np.int64(2))

# %%
np.median(df['total_bill']) # since mean is 19 and it is 17.795 indicates there are some outliers.
# Out:
# np.float64(17.795)
