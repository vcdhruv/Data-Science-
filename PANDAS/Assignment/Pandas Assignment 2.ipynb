# %%
import pandas as pd

# %%
# Q1. List any five functions of the pandas library with execution.

# %%
print("Five Pandas Functions Are:")
print("""
read_csv(),
merge(),
dropna(),
describe(),
fillna()
""")
# Out:
# Five Pandas Functions Are:
#
# read_csv(),
# merge(),
# dropna(),
# describe(),
# fillna()

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.fillna("xyz")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1 = pd.DataFrame({
    'key1':[1,22,3],
    'key2':[4,5,6],
    'key3':[7,8,9]
})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     7
# 1    22     5     8
# 2     3     6     9

# %%
data2 = pd.DataFrame({
    'key1':[1,22,33],
    'key4':[4,5,66],
    'key5':[88,8,9]
})

# %%
data2
# Out:
#    key1  key4  key5
# 0     1     4    88
# 1    22     5     8
# 2    33    66     9

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     7     4    88
# 1    22     5     8     5     8

# %%
# Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the
# DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
df1 = pd.DataFrame({
    'A':[1,2],
    'B':[3,4],
    "C":[5,6]
})

# %%
df1
# Out:
#    A  B  C
# 0  1  3  5
# 1  2  4  6

# %%
def reindex_dataframe(df):
    new_index = pd.RangeIndex(start=1,step=2,stop=2*len(df)+1)
    df = df.reset_index(drop=True)
    df.index = new_index
    return df

# %%
new_df1 = reindex_dataframe(df1)

# %%
new_df1
# Out:
#    A  B  C
# 1  1  3  5
# 3  2  4  6

# %%
# Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that
# iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The
# function should print the sum to the console.
# For example, if the 'Values' column of df contains the values [10, 20, 30, 40, 50], your function should
# calculate and print the sum of the first three values, which is 60.

# %%
df2 = pd.DataFrame({
    "Values":[10,20,30,40,50]
})

# %%
def sumOfThree(df):
    print("Sum Of First Three Values Is:{}".format(sum(df['Values'][0:3])))

# %%
sumOfThree(df2)
# Out:
# Sum Of First Three Values Is:60

# %%
# Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column
# 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
df3 = pd.DataFrame({
    'Text':["Hello, I'm Vishmay" , "I'm in data science 2.0 batch" , "I'm here to learn and get a high paying job in industry"]
})

# %%
def addNewCol(df,col_name):
    df[col_name] = df['Text'].apply(lambda x : len(x.split()))
    return df

# %%
addNewCol(df3,'Word_Count')
# Out:
#                                                 Text  Word_Count
# 0                                 Hello, I'm Vishmay           3
# 1                      I'm in data science 2.0 batch           6
# 2  I'm here to learn and get a high paying job in...          12

# %%
# Q5. How are DataFrame.size() and DataFrame.shape() different?

# %%
print("""DataFrame.size:

The DataFrame.size attribute returns the total number of elements in the DataFrame.
It is calculated as the product of the number of rows and the number of columns in the DataFrame.
The returned value represents the total number of cells or elements in the DataFrame, including both data values and missing/NaN values.
The size attribute returns a single integer value.

DataFrame.shape:

The DataFrame.shape attribute returns a tuple that represents the dimensions of the DataFrame.
It returns the number of rows followed by the number of columns in the DataFrame.
The returned value provides information about the structure of the DataFrame, indicating its shape.
The shape attribute returns a tuple with two values.""")
# Out:
# DataFrame.size:
#
# The DataFrame.size attribute returns the total number of elements in the DataFrame.
# It is calculated as the product of the number of rows and the number of columns in the DataFrame.
# The returned value represents the total number of cells or elements in the DataFrame, including both data values and missing/NaN values.
# The size attribute returns a single integer value.
#
# DataFrame.shape:
#
# The DataFrame.shape attribute returns a tuple that represents the dimensions of the DataFrame.
# It returns the number of rows followed by the number of columns in the DataFrame.
# The returned value provides information about the structure of the DataFrame, indicating its shape.
# The shape attribute returns a tuple with two values.

# %%
df3.size
# Out:
# 6

# %%
df3.shape
# Out:
# (3, 2)

# %%
# Q6. Which function of pandas do we use to read an excel file?

# %%
print("read_excel('file name here') ")
# Out:
# read_excel('file name here')

# %%
# Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email
# addresses in the format 'username@domain.com'. Write a Python function that creates a new column
# 'Username' in df that contains only the username part of each email address.

# %%
df4 = pd.DataFrame({
    'Email':['vcdhruv777@gmail.com','john.doe@example.com']
})

# %%
def usernameCol(df):
    df['Username'] = df['Email'].apply(lambda x:x.split('@')[0])
    return df

# %%
df4 = usernameCol(df4)

# %%
df4
# Out:
#                   Email    Username
# 0  vcdhruv777@gmail.com  vcdhruv777
# 1  john.doe@example.com    john.doe

# %%
# Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects
# all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The
# function should return a new DataFrame that contains only the selected rows.

# %%
df5 = pd.DataFrame({
    'A':[3,8,6,2,9],
    'B':[5,2,9,3,1],
    'C':[1,7,4,5,2]
})

# %%
def newDataframe(df):
    new_df = df[(df['A'] > 5) & (df['B'] < 10)]
    return new_df

# %%
newDataframe(df5)
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %%
# Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,
# median, and standard deviation of the values in the 'Values' column.

# %%
df6 = pd.DataFrame({
    'Values':[1,2,3,4,5]
})

# %%
def meanMedianMode(df):
    print("Mean:{} \nMedian:{} \nStandard Deviation:{}".format(df['Values'].mean(),df['Values'].median(),df['Values'].std()))

# %%
meanMedianMode(df6)
# Out:
# Mean:3.0
# Median:3.0
# Standard Deviation:1.5811388300841898

# %%
# Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to
# create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days
# for each row in the DataFrame. The moving average should be calculated using a window of size 7 and
# should include the current day.

# %%
df7 = pd.DataFrame({
    'Sales':[10,15,18,16,20,25,60],
    'Date':pd.date_range(start='2023-06-21',periods=7)
})

# %%
def movingAverage(df):
    df['MovingAverage'] = df['Sales'].rolling(window=7,min_periods=1).mean()
    return df

# %%
movingAverage(df7)
# Out:
#    Sales       Date  MovingAverage
# 0     10 2023-06-21      10.000000
# 1     15 2023-06-22      12.500000
# 2     18 2023-06-23      14.333333
# 3     16 2023-06-24      14.750000
# 4     20 2023-06-25      15.800000
# 5     25 2023-06-26      17.333333
# 6     60 2023-06-27      23.428571

# %%
# Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new
# column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.
# Monday, Tuesday) corresponding to each date in the 'Date' column.

# %%
df8 = pd.DataFrame({
    'Date':pd.date_range(start='2023-07-05',end='2023-09-05')
})

# %%
df8
# Out:
#          Date
# 0  2023-07-05
# 1  2023-07-06
# 2  2023-07-07
# 3  2023-07-08
# 4  2023-07-09
# ..        ...
# 58 2023-09-01
# 59 2023-09-02
# 60 2023-09-03
# 61 2023-09-04
# 62 2023-09-05
#
# [63 rows x 1 columns]

# %%
def days(df):
    df['Days'] = df['Date'].dt.day_name()
    return df

# %%
days(df8)
# Out:
#          Date       Days
# 0  2023-07-05  Wednesday
# 1  2023-07-06   Thursday
# 2  2023-07-07     Friday
# 3  2023-07-08   Saturday
# 4  2023-07-09     Sunday
# ..        ...        ...
# 58 2023-09-01     Friday
# 59 2023-09-02   Saturday
# 60 2023-09-03     Sunday
# 61 2023-09-04     Monday
# 62 2023-09-05    Tuesday
#
# [63 rows x 2 columns]

# %%
# Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python
# function to select all rows where the date is between '2023-01-01' and '2023-01-31'.

# %%
def select_rows_between_dates(df, start_date, end_date):
    df['Date'] = pd.to_datetime(df['Date'])
    mask = (df['Date'] >= start_date) & (df['Date'] <= end_date)
    selected_rows = df.loc[mask]
    return selected_rows

# %%
data = {'Date': ['2023-01-01', '2023-01-15', '2023-01-31', '2023-02-10']}
df9 = pd.DataFrame(data)

selected_df = select_rows_between_dates(df, '2023-01-01', '2023-01-31')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25724\2480205102.py in <module>
#       2 df9 = pd.DataFrame(data)
#       3
# ----> 4 selected_df = select_rows_between_dates(df, '2023-01-01', '2023-01-31')
#
# NameError: name 'df' is not defined
