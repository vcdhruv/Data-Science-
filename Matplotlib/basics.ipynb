# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0,10,200)

# %%
x
# Out:
# array([ 0.        ,  0.05025126,  0.10050251,  0.15075377,  0.20100503,
#         0.25125628,  0.30150754,  0.35175879,  0.40201005,  0.45226131,
#         0.50251256,  0.55276382,  0.60301508,  0.65326633,  0.70351759,
#         0.75376884,  0.8040201 ,  0.85427136,  0.90452261,  0.95477387,
#         1.00502513,  1.05527638,  1.10552764,  1.15577889,  1.20603015,
#         1.25628141,  1.30653266,  1.35678392,  1.40703518,  1.45728643,
#         1.50753769,  1.55778894,  1.6080402 ,  1.65829146,  1.70854271,
#         1.75879397,  1.80904523,  1.85929648,  1.90954774,  1.95979899,
#         2.01005025,  2.06030151,  2.11055276,  2.16080402,  2.21105528,
#         2.26130653,  2.31155779,  2.36180905,  2.4120603 ,  2.46231156,
#         2.51256281,  2.56281407,  2.61306533,  2.66331658,  2.71356784,
#         2.7638191 ,  2.81407035,  2.86432161,  2.91457286,  2.96482412,
#         3.01507538,  3.06532663,  3.11557789,  3.16582915,  3.2160804 ,
# ...

# %%
y = np.sin(x)

# %%
y
# Out:
# array([ 0.        ,  0.05023011,  0.10033341,  0.15018339,  0.19965422,
#         0.24862099,  0.29696008,  0.34454944,  0.39126893,  0.43700061,
#         0.481629  ,  0.52504145,  0.56712835,  0.60778345,  0.6469041 ,
#         0.68439153,  0.72015112,  0.75409257,  0.78613019,  0.8161831 ,
#         0.84417544,  0.87003651,  0.89370105,  0.91510929,  0.9342072 ,
#         0.95094655,  0.96528509,  0.97718662,  0.98662108,  0.99356467,
#         0.99799984,  0.99991541,  0.99930653,  0.99617474,  0.99052796,
#         0.98238043,  0.97175273,  0.95867168,  0.94317032,  0.92528777,
#         0.90506919,  0.88256563,  0.85783388,  0.8309364 ,  0.80194109,
#         0.77092115,  0.7379549 ,  0.70312557,  0.66652108,  0.62823386,
#         0.58836056,  0.54700186,  0.50426216,  0.46024937,  0.41507461,
#         0.36885193,  0.32169803,  0.27373195,  0.22507478,  0.17584939,
#         0.12618003,  0.07619211,  0.02601183, -0.02423412, -0.07441889,
# ...

# %%
plt.plot(x,y)

# %%
plt.figure(figsize=(6,2)) # for giving figure size
plt.plot(x,y,'--r') # --r means red dotted line , --b means blue dotted line
plt.xlabel("this is my x data") # label x
plt.ylabel("this is my y data") # label y
plt.title("This is my title") # label title
plt.grid() # to show grid lines
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x, y) # scatter

# %%
x
# Out:
# array([0.96842879, 0.09592677, 0.44855582, 0.85459611, 0.40556975,
#        0.47090428, 0.06050418, 0.65817151, 0.3134923 , 0.28703122,
#        0.18379134, 0.55416757, 0.03248617, 0.68444415, 0.43052821,
#        0.4643579 , 0.85134958, 0.80889116, 0.18147599, 0.87411743,
#        0.12721496, 0.11554212, 0.66844772, 0.09173381, 0.35964038,
#        0.84183743, 0.93017442, 0.87553751, 0.73105449, 0.86000005,
#        0.5131075 , 0.04478091, 0.24196775, 0.39651632, 0.64253817,
#        0.05527618, 0.31409877, 0.73644569, 0.74228554, 0.92949367,
#        0.60502214, 0.29719857, 0.62757898, 0.4420486 , 0.48072931,
#        0.04535254, 0.9852916 , 0.23232276, 0.90153896, 0.81800865])

# %%
y
# Out:
# array([0.59839715, 0.86113294, 0.4807822 , 0.47909246, 0.84195995,
#        0.16518817, 0.38569561, 0.53767331, 0.61979853, 0.7031404 ,
#        0.916464  , 0.40957371, 0.08250496, 0.09053077, 0.97262703,
#        0.04906851, 0.18412792, 0.20497136, 0.7715227 , 0.80335796,
#        0.2030056 , 0.93841453, 0.84372933, 0.59229777, 0.36196587,
#        0.46555554, 0.89450849, 0.97086048, 0.54354967, 0.30133457,
#        0.30737731, 0.69536564, 0.80152439, 0.43539218, 0.21744191,
#        0.79433541, 0.80778614, 0.49344044, 0.31905209, 0.24330126,
#        0.12263377, 0.53836464, 0.30595329, 0.80555072, 0.5450498 ,
#        0.30484581, 0.99708113, 0.29539784, 0.70211035, 0.66001448])

# %%
colors = np.random.rand(50)
sizes = 1000 * np.random.rand(50)
plt.scatter(x, y, c=colors , s = sizes , alpha= 0.7) # colors , sizes and intensity
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("random data")
# Out:
# Text(0.5, 1.0, 'random data')

# %%
x = ['a','b','c','d','e']

# %%
y = np.random.rand(5)

# %%
plt.bar(x,y) # bar chart
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Bar chart")
# Out:
# Text(0.5, 1.0, 'Bar chart')

# %%
y
# Out:
# array([0.71836773, 0.24874233, 0.47647443, 0.53116893, 0.59055424])

# %%
plt.barh(x,y) # horizontal bar chart
# Out:
# <BarContainer object of 5 artists>

# %%
x = np.random.rand(50)
y = np.random.rand(50)
colors = np.random.rand(50)
sizes = 1000 * np.random.rand(50)
plt.scatter(x, y, c="#0f0f0f" , s = sizes , alpha= 0.7 ,marker='v') # colors , sizes , intensity and marker
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("random data")
# Out:
# Text(0.5, 1.0, 'random data')

# %%
x = [4,5,6,7,8,9]
y = [6,7,8,9,10,11]
plt.plot(x,y)
plt.show()

# %%
# get the intensity of numbers in graph

# %%
data = [1,2,3,4,5,1,2,3,6,7,8,1,2,3]

# %%
plt.hist(data) # histogram
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,30,80,19,40,1]
color = ['red','blue','#0f0f0f','#DFC010','#EC801C','yellow']
plt.scatter(x,y,c=color)
plt.show()

# %%
# 3d graph
import numpy as np

# %%
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(x,y,z)

# %%
import matplotlib.pyplot as plt

# %%
x = [10,20,30,40]
labels = ['a','b','c','d']
colors = ['red','gold','green','blue']
explode = (0.2,0,0,0) # move out the first slice

plt.pie(x,labels=labels,colors=colors,autopct="%1.1f%%",shadow=True , explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x215ce709be0>,
# ...
#  [Text(1.2363734676717335, 0.4017221034961523, 'a'),
#   Text(0.33991865722907993, 1.0461621798113232, 'b'),
#   Text(-1.046162235191088, 0.33991848678762215, 'c'),
#   Text(0.33991884014588697, -1.0461621203780394, 'd')],
#  [Text(0.7608452108749129, 0.24721360215147833, '10.0%'),
#   Text(0.18541017667040724, 0.5706339162607217, '20.0%'),
#   Text(-0.5706339464678661, 0.18541008370233936, '30.0%'),
#   Text(0.18541027644321104, -0.5706338838425669, '40.0%')])
