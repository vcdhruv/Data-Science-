# %%
import pandas as pd

# %%
df1 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop('PassengerId',axis=1,inplace=True)

# %%
df.drop(3,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# set Name column as index of the datafram

# %%
df.set_index("Name",inplace=True)

# %%
df.reset_index()
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df = pd.read_csv("taxonomy.csv.xls")

# %%
df
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
# to remove rows on basis of nan

# %%
df.dropna(inplace=True)

# %%
# t remove column on basis of nan

# %%
df.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
# to fill nan

# %%
df.fillna("vcd")
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       vcd                   vcd
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.drop('PassengerId',axis=1,inplace=True)

# %%
df1.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
# now group by operations

# %%
# find average fare paid by people who have not survived

# %%
g = df1.groupby('Survived')

# %%
g

# %%
g.sum()
# Out:
#           Pclass                                               Name  \
# Survived
# 0           1390  Braund, Mr. Owen HarrisAllen, Mr. William Henr...
# 1            667  Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#                                                         Sex       Age  SibSp  \
# Survived
# 0         malemalemalemalemalemalemalefemalemalefemalema...  12985.50    304
# 1         femalefemalefemalefemalefemalefemalefemalefema...   8219.67    162
#
#           Parch                                             Ticket  \
# Survived
# 0           181  A/5 2117137345033087717463349909A/5. 215134708...
# 1           159  PC 17599STON/O2. 3101282113803347742237736PP 9...
#
#                 Fare                                              Cabin  \
# Survived
# 0         12142.7199  E46C23 C25 C27B30C83F G73E31A5D26C110B58 B60D2...
# 1         16551.2294  C85C123G6C103D56A6B78D33C52B28F33C23 C25 C27D1...
#
# ...

# %%
g.sum().transpose()
# Out:
# Survived                                                  0  \
# Pclass                                                 1390
# Name      Braund, Mr. Owen HarrisAllen, Mr. William Henr...
# Sex       malemalemalemalemalemalemalefemalemalefemalema...
# Age                                                 12985.5
# SibSp                                                   304
# Parch                                                   181
# Ticket    A/5 2117137345033087717463349909A/5. 215134708...
# Fare                                             12142.7199
# Cabin     E46C23 C25 C27B30C83F G73E31A5D26C110B58 B60D2...
# Embarked  SSQSSSSSQSSSCSSCSCSSSSSCSQCSSSCCSCSSCSSSSSCSSS...
#
# Survived                                                  1
# Pclass                                                  667
# Name      Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex       femalefemalefemalefemalefemalefemalefemalefema...
# Age                                                 8219.67
# ...

# %%
df1
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
f1 = df1[['Survived', 'Pclass','Age']][0:5]

# %%
f2 = df1[['Survived', 'Pclass','Age']][5:10]

# %%
f1
# Out:
#    Survived  Pclass   Age
# 0         0       3  22.0
# 1         1       1  38.0
# 2         1       3  26.0
# 3         1       1  35.0
# 4         0       3  35.0

# %%
f2
# Out:
#    Survived  Pclass   Age
# 5         0       3   NaN
# 6         0       1  54.0
# 7         0       3   2.0
# 8         1       3  27.0
# 9         1       2  14.0

# %%
pd.concat([f1,f2])
# Out:
#    Survived  Pclass   Age
# 0         0       3  22.0
# 1         1       1  38.0
# 2         1       3  26.0
# 3         1       1  35.0
# 4         0       3  35.0
# 5         0       3   NaN
# 6         0       1  54.0
# 7         0       3   2.0
# 8         1       3  27.0
# 9         1       2  14.0

# %%
pd.concat([f1,f2],axis=1)
# Out:
#    Survived  Pclass   Age  Survived  Pclass   Age
# 0       0.0     3.0  22.0       NaN     NaN   NaN
# 1       1.0     1.0  38.0       NaN     NaN   NaN
# 2       1.0     3.0  26.0       NaN     NaN   NaN
# 3       1.0     1.0  35.0       NaN     NaN   NaN
# 4       0.0     3.0  35.0       NaN     NaN   NaN
# 5       NaN     NaN   NaN       0.0     3.0   NaN
# 6       NaN     NaN   NaN       0.0     1.0  54.0
# 7       NaN     NaN   NaN       0.0     3.0   2.0
# 8       NaN     NaN   NaN       1.0     3.0  27.0
# 9       NaN     NaN   NaN       1.0     2.0  14.0

# %%
df2 = pd.concat([f1,f2],axis=1)

# %%
df2.fillna("vcd",inplace=True)

# %%
df2
# Out:
#   Survived Pclass   Age Survived Pclass   Age
# 0      0.0    3.0  22.0      vcd    vcd   vcd
# 1      1.0    1.0  38.0      vcd    vcd   vcd
# 2      1.0    3.0  26.0      vcd    vcd   vcd
# 3      1.0    1.0  35.0      vcd    vcd   vcd
# 4      0.0    3.0  35.0      vcd    vcd   vcd
# 5      vcd    vcd   vcd      0.0    3.0   vcd
# 6      vcd    vcd   vcd      0.0    1.0  54.0
# 7      vcd    vcd   vcd      0.0    3.0   2.0
# 8      vcd    vcd   vcd      1.0    3.0  27.0
# 9      vcd    vcd   vcd      1.0    2.0  14.0

# %%
# merge operation

# %%
data1 = pd.DataFrame({
    'Key1':[1,2,4,5,6],
    'Key2':[4,5,6,7,8],
    'Key3':[3,4,5,6,60]
})

# %%
data1
# Out:
#    Key1  Key2  Key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8    60

# %%
data2 = pd.DataFrame({
    'Key1':[1,2,45,6,67],
    'Key4':[56,5,6,7,8],
    'Key5':[3,56,5,6,60]
})

# %%
data2
# Out:
#    Key1  Key4  Key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8    60

# %%
data1
# Out:
#    Key1  Key2  Key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8    60

# %%
data2
# Out:
#    Key1  Key4  Key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8    60

# %%
pd.merge(data1,data2) # inner merge
# Out:
#    Key1  Key2  Key3  Key4  Key5
# 0     1     4     3    56     3
# 1     2     5     4     5    56
# 2     6     8    60     7     6

# %%
pd.merge(data1,data2,how='left') # left merge
# Out:
#    Key1  Key2  Key3  Key4  Key5
# 0     1     4     3  56.0   3.0
# 1     2     5     4   5.0  56.0
# 2     4     6     5   NaN   NaN
# 3     5     7     6   NaN   NaN
# 4     6     8    60   7.0   6.0

# %%
pd.merge(data1,data2,how='right') # right merge
# Out:
#    Key1  Key2  Key3  Key4  Key5
# 0     1   4.0   3.0    56     3
# 1     2   5.0   4.0     5    56
# 2    45   NaN   NaN     6     5
# 3     6   8.0  60.0     7     6
# 4    67   NaN   NaN     8    60

# %%
pd.merge(data1,data2,how='outer') # full outer merge
# Out:
#    Key1  Key2  Key3  Key4  Key5
# 0     1   4.0   3.0  56.0   3.0
# 1     2   5.0   4.0   5.0  56.0
# 2     4   6.0   5.0   NaN   NaN
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0  60.0   7.0   6.0
# 5    45   NaN   NaN   6.0   5.0
# 6    67   NaN   NaN   8.0  60.0

# %%
pd.merge(data1,data2,how='cross') # cross merge
# Out:
#     Key1_x  Key2  Key3  Key1_y  Key4  Key5
# 0        1     4     3       1    56     3
# 1        1     4     3       2     5    56
# 2        1     4     3      45     6     5
# 3        1     4     3       6     7     6
# 4        1     4     3      67     8    60
# 5        2     5     4       1    56     3
# 6        2     5     4       2     5    56
# 7        2     5     4      45     6     5
# 8        2     5     4       6     7     6
# 9        2     5     4      67     8    60
# 10       4     6     5       1    56     3
# 11       4     6     5       2     5    56
# 12       4     6     5      45     6     5
# 13       4     6     5       6     7     6
# 14       4     6     5      67     8    60
# 15       5     7     6       1    56     3
# 16       5     7     6       2     5    56
# 17       5     7     6      45     6     5
# 18       5     7     6       6     7     6
# 19       5     7     6      67     8    60
# 20       6     8    60       1    56     3
# ...

# %%
# join operation 
# for join operation both data column name must be different otherwise it will overlap

# %%
data1 = pd.DataFrame({
    'Key1':[1,2,4,5,6],
    'Key2':[4,5,6,7,8],
    'Key3':[3,4,5,6,60]
},index=['a','b','c','d','e'])

# %%
data2 = pd.DataFrame({
    'Key11':[1,2,45,6,67],
    'Key4':[56,5,6,7,8],
    'Key5':[3,56,5,6,60]
},index=['a','b','h','i','j'])

# %%
data1.join(data2)
# Out:
#    Key1  Key2  Key3  Key11  Key4  Key5
# a     1     4     3    1.0  56.0   3.0
# b     2     5     4    2.0   5.0  56.0
# c     4     6     5    NaN   NaN   NaN
# d     5     7     6    NaN   NaN   NaN
# e     6     8    60    NaN   NaN   NaN

# %%
df1
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df1['Fare_RS'] = df1['Fare'].apply(lambda x : x*80)

# %%
df1
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
df1['Name_len'] = df1['Name'].apply(len)

# %%
df1
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
def cat_fare(x):
    if x < 10:
        return "cheap"
    elif x >= 10 and x < 20:
        return "mid"
    else:
        return "high"

# %%
df1["Catergories_fare"] = df1['Fare'].apply(cat_fare)

# %%
df1
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...
