# %% [markdown]
# #### Explain GET and POST methods.

# %%
print("The GET method is used to request data from a specified resource. It is intended for retrieving data without affecting the resource on the server.")
print("\nThe POST method is used to send data to a server to create or update a resource. It is intended for operations that can have side effects on the server.")
print("\n GET method is used to get data from url while POST method is used to send data through body.")
# Out:
# The GET method is used to request data from a specified resource. It is intended for retrieving data without affecting the resource on the server.
#
# The POST method is used to send data to a server to create or update a resource. It is intended for operations that can have side effects on the server.
#
#  GET method is used to get data from url while POST method is used to send data through body.

# %% [markdown]
# #### Why is request used in Flask?

# %%
print("In Flask, the request object is used to handle incoming data from HTTP requests")
# Out:
# In Flask, the request object is used to handle incoming data from HTTP requests

# %% [markdown]
# #### Why is redirect() used in Flask?

# %%
print("In Flask, the redirect() function is used to redirect the client to a different URL.")
# Out:
# In Flask, the redirect() function is used to redirect the client to a different URL.

# %% [markdown]
# #### What are templates in Flask? Why is the render_template() function used?

# %%
print("In Flask, templates are used to generate dynamic HTML pages by combining static HTML with data provided by your application")
# Out:
# In Flask, templates are used to generate dynamic HTML pages by combining static HTML with data provided by your application

# %% [markdown]
# #### Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %% [markdown]
# ## get all

# %% [markdown]
# ![Screenshot%202024-08-05%20155101.png](attachment:Screenshot%202024-08-05%20155101.png)

# %% [markdown]
# ## get by id

# %% [markdown]
# ![Screenshot%202024-08-05%20155158.png](attachment:Screenshot%202024-08-05%20155158.png)

# %% [markdown]
# ## post new item

# %% [markdown]
# ![Screenshot%202024-08-05%20155345.png](attachment:Screenshot%202024-08-05%20155345.png)

# %% [markdown]
# ![Screenshot%202024-08-05%20155419.png](attachment:Screenshot%202024-08-05%20155419.png)

# %% [markdown]
# ## update item

# %% [markdown]
# ![Screenshot%202024-08-05%20155530.png](attachment:Screenshot%202024-08-05%20155530.png)

# %% [markdown]
# ![Screenshot%202024-08-05%20155557.png](attachment:Screenshot%202024-08-05%20155557.png)

# %% [markdown]
# ## delete item

# %% [markdown]
# ![Screenshot%202024-08-05%20155632.png](attachment:Screenshot%202024-08-05%20155632.png)

# %% [markdown]
# ![Screenshot%202024-08-05%20155703.png](attachment:Screenshot%202024-08-05%20155703.png)

# %% [markdown]
# #### complete code for api : https://github.com/vcdhruv/Data-Science-/blob/main/Python/Projects/Simple%20Flask%20Api/app.py
